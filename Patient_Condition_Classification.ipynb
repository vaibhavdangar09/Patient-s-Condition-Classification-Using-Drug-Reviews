# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavdangar09/Patient-s-Condition-Classification-Using-Drug-Reviews/blob/main/Patient_Condition_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Patient's Condition Classification Using Drug Reviews**

# %% [markdown]
# ### **Project Overview:**
#
#
# ---
#
#
# * Reviews are very important to get the overview of product whether it is service, offerings or products.
#
# * Reviews also plays a very important role in healthcare domain especially in terms of drugs.
#
# * By analyzing the reviews, we can get the understanding of the drug effectiveness and its side effects.
#
# * But in this project, we will classify the condition of patient based on his review so that we can recommend him a suitable drug.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,mean_squared_error
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# libraries for data preprocessing
from wordcloud import STOPWORDS
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
import re
import nltk
import string
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # **Load Data Set**

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load train and test data
patient_review_train  = pd.read_csv('/content/drive/MyDrive/drugsComTrain_raw.csv')
patient_review_test  = pd.read_csv('/content/drive/MyDrive/drugsComTest_raw.csv')

# %% [markdown]
# ### **Dataset First View**

# %%
patient_review_train.sample(10)
# Out:
#         uniqueID                          drugName                  condition  \
# 25423     192550  Drospirenone / ethinyl estradiol              Birth Control
# 151680     13114                            Xolair                  Urticaria
# 96699     102533                      Aripiprazole                 Depression
# 54052       8132                          Zolpidem                   Insomnia
# 155936     33956                   Junel Fe 1 / 20  Polycystic Ovary Syndrome
# 151662     34584                           Tysabri         Multiple Sclerosis
# 73085      17785  Ethinyl estradiol / etonogestrel              Birth Control
# 3997      186089                    Desvenlafaxine   Major Depressive Disorde
# 144723    138389                       Phentermine                Weight Loss
# 53295     195554                            Aviane              Birth Control
#
#                                                    review  rating       date  \
# 25423   "I got on this birth control when it first cam...       9  14-Aug-13
# 151680  "I&#039;ve had hives off and on since 2002. I ...       3  28-Jun-17
# 96699   "I was told by my doctor that I might gain wei...       8  25-Apr-16
# 54052   "I&#039;ve been taking 10 mg.  every night for...      10  23-Jul-17
# 155936  "I really liked this birth control. I only exp...      10   4-Jul-14
# 151662  "I have just had my second infusion and from t...      10   5-Aug-13
# 73085   "10+ years on it. Can&#039;t feel it. Never fa...      10  23-May-15
# 3997    "I suffer from GAD, what is depression, anxiet...       9  15-Jul-15
# 144723  "I posted a thread on January 31, 2014. I weig...      10   7-Feb-14
# 53295   "I tried taking Junel Fe for a month and it wa...      10  25-Jan-12
#
#         usefulCount
# 25423            25
# 151680           10
# 96699            36
# 54052             9
# 155936           23
# 151662           85
# 73085            18
# 3997              6
# 144723           41
# 53295             3

# %%
patient_review_test.sample(10)
# Out:
#        uniqueID                          drugName            condition  \
# 49283    106169                     Oxymetazoline     Nasal Congestion
# 26269     65812                       Propranolol        mance Anxiety
# 16425    226526                      Etonogestrel        Birth Control
# 49630     11761                         Trulicity     Diabetes, Type 2
# 33551      5373                          Cryselle        Birth Control
# 23929    165142          Phentermine / topiramate          Weight Loss
# 41269    123958                             Skyla        Birth Control
# 51479    161869                     Ciprofloxacin    Kidney Infections
# 21314    155466                     Metronidazole  Bacterial Infection
# 41754    224058  Aspirin / carisoprodol / codeine         Muscle Spasm
#
#                                                   review  rating       date  \
# 49283  "I tried this product as a result of a bad day...       2  19-Aug-09
# 26269  "I am absolutely amazed at how well this medic...      10  12-Feb-16
# 16425  "Had this placed a two and a half years ago. P...       7  26-Jun-15
# 49630  "I can agree that the fatigue is noticeable. M...       8  15-Jun-16
# 33551  "I&#039;m 18 and have been on Cryselle for aro...       8  24-Feb-17
# 23929  "I have only been using Qsymia for one week bu...      10  15-Aug-14
# 41269  "Insertion process was extremely painful (brok...       3   5-Aug-16
# 51479  "I was put on Cipro for an acute kidney infect...       2  27-Aug-17
# 21314  "I am currently on this to treat BV, I&#039;m ...       8  11-May-15
# 41754  "I was being plagued by severe coughing attack...       9  25-Feb-09
#
#        usefulCount
# 49283           11
# 26269           18
# 16425            2
# 49630           17
# 33551            6
# 23929           66
# 41269            5
# 51479            2
# 21314           10
# 41754           23

# %% [markdown]
# ## **Dataset Rows And Columns Count**

# %%
# Train Dataset Rows and Columns Count
print(patient_review_train.shape)
# Out:
# (161297, 7)

# %% [markdown]
# * In Training Data: 161297 onservations and 7 features are available.

# %%
# Test Dataset Rows and Columns Count
print(patient_review_test.shape)
# Out:
# (53766, 7)

# %% [markdown]
# * In Test Data: 53766 onservations and 7 features are available.

# %% [markdown]
# ## **Dataset Information**

# %%
# train dataset information
print(patient_review_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161297 entries, 0 to 161296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     161297 non-null  int64
#  1   drugName     161297 non-null  object
#  2   condition    160398 non-null  object
#  3   review       161297 non-null  object
#  4   rating       161297 non-null  int64
#  5   date         161297 non-null  object
#  6   usefulCount  161297 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 8.6+ MB
# None

# %% [markdown]
# * 2 Features has a int64 data type
#
# * 5 Fetaures has a object data type

# %%
# test dataset information
print(patient_review_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53766 entries, 0 to 53765
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   uniqueID     53766 non-null  int64
#  1   drugName     53766 non-null  object
#  2   condition    53471 non-null  object
#  3   review       53766 non-null  object
#  4   rating       53766 non-null  int64
#  5   date         53766 non-null  object
#  6   usefulCount  53766 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 2.9+ MB
# None

# %% [markdown]
# ## **Checking Duplicate Values**

# %%
# check duplicate values for training data

patient_review_train.duplicated().value_counts()
# Out:
# False    161297
# Name: count, dtype: int64

# %% [markdown]
# * No duplicate values are present in our data set.

# %%
# check duplicate values for test data

patient_review_test.duplicated().value_counts()
# Out:
# False    53766
# Name: count, dtype: int64

# %% [markdown]
# * No duplicate values are present in our test data set.

# %% [markdown]
# ## **Checking Missing/Null Values**

# %%
# checking missing values on train dataset

print(patient_review_train.isnull().sum())
# Out:
# uniqueID         0
# drugName         0
# condition      899
# review           0
# rating           0
# date             0
# usefulCount      0
# dtype: int64

# %% [markdown]
# * 899 missing values are present in our training data set.

# %%
# checking missing values on test dataset
print(patient_review_test.isnull().sum())
# Out:
# uniqueID         0
# drugName         0
# condition      295
# review           0
# rating           0
# date             0
# usefulCount      0
# dtype: int64

# %% [markdown]
# * 295 missing values are present in our training data set.

# %%
# count percentage wise missing values dataset
def missing_value_check(df):

  per_miss_values = patient_review_train.isnull().sum() * 100 / len(patient_review_train)
  miss_values_df = pd.DataFrame({'Feature_name':patient_review_train.columns,
                                 'percentage':per_miss_values})
  return miss_values_df.sort_values('percentage',ascending=False)

# %%
missing_value_check(patient_review_train)
# Out:
#             Feature_name  percentage
# condition      condition    0.557357
# uniqueID        uniqueID    0.000000
# drugName        drugName    0.000000
# review            review    0.000000
# rating            rating    0.000000
# date                date    0.000000
# usefulCount  usefulCount    0.000000

# %% [markdown]
# * Here 0.55% values are missing, Imputation might be a reasonable approach,so i will apply mode imputation.

# %% [markdown]
# ## **Handling Missing Values**

# %%
# handling missing value in training data

patient_review_train = patient_review_train.fillna(patient_review_train['condition'].mode().iloc[0])

# %%
# handling missing value in test data

patient_review_test = patient_review_test.fillna(patient_review_test['condition'].mode().iloc[0])

# %%
# checking missing values on train dataset
print(patient_review_train.isnull().sum())
# Out:
# uniqueID       0
# drugName       0
# condition      0
# review         0
# rating         0
# date           0
# usefulCount    0
# dtype: int64

# %%
# checking missing values on test dataset
print(patient_review_test.isnull().sum())
# Out:
# uniqueID       0
# drugName       0
# condition      0
# review         0
# rating         0
# date           0
# usefulCount    0
# dtype: int64

# %% [markdown]
# * No missing values are found after imputation.

# %% [markdown]
# ## **Data Cleaning**

# %%
# Define the conditions to keep
keep_conditions = ["Depression", "High Blood Pressure", "Diabetes, Type 2"]

# Filter the DataFrame to only keep the records with the specified conditions
review_train_df = patient_review_train[patient_review_train['condition'].isin(keep_conditions)]

review_train_df.drop(['uniqueID'],axis =1,inplace=True)

review_train_df.drop(['date'],axis =1,inplace=True)

review_train_df.head()
# Out:
#           drugName         condition  \
# 11  L-methylfolate        Depression
# 31      Sertraline        Depression
# 44     Venlafaxine        Depression
# 50     Dulaglutide  Diabetes, Type 2
# 67      Effexor XR        Depression
#
#                                                review  rating  usefulCount
# 11  "I have taken anti-depressants for years, with...      10           54
# 31  "1 week on Zoloft for anxiety and mood swings....       8            3
# 44  "my gp started me on Venlafaxine yesterday to ...       4            3
# 50  "Hey Guys,  It&#039;s been 4 months since my l...      10           24
# 67  "This medicine saved my life. I was at my wits...      10          166

# %%
# Define the conditions to keep
keep_conditions = ["Depression", "High Blood Pressure", "Diabetes, Type 2"]

# Filter the DataFrame to only keep the records with the specified conditions
review_test_df = patient_review_test[patient_review_test['condition'].isin(keep_conditions)]

review_test_df.drop(['date'],axis =1,inplace=True)

review_test_df.head()
# Out:
#     uniqueID      drugName         condition  \
# 0     163740   Mirtazapine        Depression
# 35    101149         Actos  Diabetes, Type 2
# 38    141462  Escitalopram        Depression
# 67    201582        Zoloft        Depression
# 73    131683    Effexor XR        Depression
#
#                                                review  rating  usefulCount
# 0   "I&#039;ve tried a few antidepressants over th...      10           22
# 35  "Have been on Actos for almost a year, gained ...       4           42
# 38  "I am a 22 year old female college student. I ...       9           32
# 67  "Zoloft did not help me at all.  I was on it f...       1           51
# 73  "Sadly only lasted 5 days on Effexor XR. The s...       1           18

# %% [markdown]
# ## **Text Preprocessing**

# %%
review_train_df['review']
# Out:
# 11        "I have taken anti-depressants for years, with...
# 31        "1 week on Zoloft for anxiety and mood swings....
# 44        "my gp started me on Venlafaxine yesterday to ...
# 50        "Hey Guys,  It&#039;s been 4 months since my l...
# 67        "This medicine saved my life. I was at my wits...
#                                 ...
# 161251    "It is fourth blood pressure pill for me. It f...
# 161258    "While on Bystolic my feet and arms were numb....
# 161278    "I just got diagnosed with type 2. My doctor p...
# 161286    "This is the third med I&#039;ve tried for anx...
# 161290    "I have only been on Tekturna for 9 days. The ...
# Name: review, Length: 13944, dtype: object

# %% [markdown]
# ### **Stop words**

# %%
# make a object of stopwords
stop = stopwords.words('english')

# %% [markdown]
# ### **Lemmatization**

# %%
# make a object of wordnetlemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def text_pre_preprocessing(review):
  # 1 remove html
  review_text = BeautifulSoup(review,'html.parser').get_text()

  # 2 make a space
  letters_only = re.sub('[^a-zA-Z]',' ',review_text)

  # 3 lower letters
  words = letters_only.lower().split()

  # 4 remove stop words
  meaningful_words = [w for w in words if not w in stop]

  # 5 apply lemmatization
  lemmatize_words = [lemmatizer.lemmatize(w) for w in meaningful_words]

  return (' '.join(lemmatize_words))

# %%
# apply pro-proceesing on train data
review_train_df['review'] = review_train_df['review'].apply(lambda x: text_pre_preprocessing(x))

# %%
# apply pre-processing on test data
review_test_df['review'] = review_test_df['review'].apply(lambda x: text_pre_preprocessing(x))

# %%
# convert target variable into numeric labels for training data

review_train_df['condition'] = review_train_df.condition.apply(lambda x:0 if x=="Depression" else(1 if x=="High Blood Pressure" else 2))

# %%
# convert target variable into numeric labels for test data
review_test_df['condition'] = review_test_df.condition.apply(lambda x:0 if x=="Depression" else(1 if x=="High Blood Pressure" else 2))

# %%
from gensim.models import Word2Vec
from keras.layers import Input, Dense, Embedding, LSTM, Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

# Step 1: Preprocess the text data and convert it into sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(review_train_df['review'])
sequences = tokenizer.texts_to_sequences(review_train_df['review'])

MAX_SEQUENCE_LENGTH = 100  # Choose an appropriate sequence length based on your data
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

# Step 2: Train Word2Vec embeddings or load pre-trained Word2Vec embeddings
# Example of training Word2Vec embeddings
word2vec_model = Word2Vec(sentences=sequences, vector_size=100, window=5, min_count=1, workers=4)

# Step 3: Map words to their corresponding Word2Vec embeddings
word_index = tokenizer.word_index
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, 100))  # Assuming vector size is 100

for word, i in word_index.items():
    if i >= num_words:
        continue
    if word in word2vec_model.wv:
        embedding_matrix[i] = word2vec_model.wv[word]

# Step 4: Build and compile the Bidirectional LSTM RNN model
input_ = Input(shape=(MAX_SEQUENCE_LENGTH,))
embedding_layer = Embedding(
    num_words,
    100,  # Assuming vector size is 100
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)
x = embedding_layer(input_)
x = Bidirectional(LSTM(15, return_sequences=True))(x)
x = GlobalMaxPool1D()(x)
output = Dense(1, activation="sigmoid")(x)

model = Model(input_, output)
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  embedding (Embedding)       (None, 100, 100)          1212600
#
#  bidirectional (Bidirection  (None, 100, 30)           13920
#  al)
#
#  global_max_pooling1d (Glob  (None, 30)                0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 1226551 (4.68 MB)
# Trainable params: 13951 (54.50 KB)
# Non-trainable params: 1212600 (4.63 MB)
# _________________________________________________________________

# %%
print(sequences)
# Out:
# [[101, 228, 264, 6, 280, 629, 693, 69, 4, 346, 76, 48, 16, 124, 629, 60, 225, 604, 100, 173, 280, 1633, 88, 22, 4511, 5676, 108, 108, 173, 7, 8, 10, 9, 14, 85, 234, 17, 12, 114, 144, 51, 4, 3], [5, 70, 15, 73, 410, 16, 1, 82, 872, 54, 2, 32, 615, 5, 37, 23, 2217, 682, 8, 1608, 826, 9, 29, 22, 179, 116, 400, 1053], [685, 11, 754, 569, 42, 7, 131, 92, 8, 34, 226, 128, 237, 987, 56, 167, 184, 233, 4, 3, 30, 23, 22, 39, 183, 32, 75, 43, 777, 731, 226, 419, 1041, 56, 64, 1054, 23, 44, 9048, 9, 22, 82, 39, 183, 32, 26, 1691, 217, 248, 1041, 226, 9049, 94, 685, 76, 182, 34, 14, 203, 71, 686, 40, 1, 71, 1, 165, 40, 149, 22], [2330, 1609, 10, 46, 75, 473, 275, 123, 10, 94, 64, 24, 266, 531, 10, 185, 527, 592, 10, 336, 188, 630, 3208, 1583, 133, 615, 197, 4, 3, 112, 35, 57, 28, 89, 17, 11, 266, 8, 1919, 32, 4, 3, 28, 126, 89, 52, 61, 1372, 1433, 27, 185, 266, 5, 94, 258, 1232, 401, 640, 1076, 4512, 1355, 307, 2331], [21, 312, 18, 2560, 351, 228, 264, 694, 123, 19, 133, 87, 97, 1085, 13, 432, 565, 107, 30, 115, 99, 343, 4, 3, 259, 873, 228, 264, 49, 954, 17, 166, 2, 1065, 433, 207, 69, 7, 30, 25, 14, 955, 143, 683, 426, 351, 2017, 23, 22, 59, 123], [11, 8, 587, 41, 43, 2728, 471, 147, 170, 2, 2490, 233, 954, 293, 16, 265, 52, 682, 903, 538, 2949, 2, 29, 607, 553, 413, 293, 903, 1692, 76, 24, 946, 37, 350, 648, 26, 29, 22, 1655, 81, 228, 264, 644, 4980, 236, 163, 61, 107, 157, 170, 1610, 2949, 1055], [1101, 99, 343, 1, 2420, 7, 15, 19, 367, 315, 39, 82, 53, 947, 874, 6557, 44, 22, 281, 100, 255, 764, 6558, 34, 232, 400, 413, 137, 6559, 2420, 654, 157, 12, 25, 1758, 80, 9, 783, 3587, 94, 118, 539, 924], [20, 36, 147, 19, 87, 749, 682, 220, 198, 1500, 1286, 137, 715, 749], [13, 276, 2, 232, 226, 11, 9, 276, 10, 102, 12, 434, 56, 430, 2111, 328, 56, 24, 1453], [261, 2268, 1233, 11, 266, 809, 49, 16, 458, 175, 120, 53, 226, 57, 28, 1225, 2, 230, 28, 110, 2059, 207, 101, 32, 40, 266, 259, 54, 50, 178, 960, 1920, 2950, 82, 38, 42, 30, 207, 55, 117, 299, 668, 1194, 566, 32, 5, 24, 331, 554, 191, 107, 266, 809, 1563, 1434, 270, 150, 2], [6560, 319, 11, 31, 461, 17, 5, 26, 58, 130, 11, 8, 791, 97, 10, 31, 407, 8, 1, 2, 783, 56, 388, 319, 210, 1325, 1373, 11, 439, 593, 123, 755, 622, 555, 1086, 1134, 561, 25, 443, 8, 10, 40, 3834, 368, 101, 358, 791, 95, 439, 2218], [38, 432, 135, 511, 756, 4, 3, 404, 5, 317, 73, 122, 22, 51, 580, 18, 1341, 837, 755, 341, 3588, 136, 686, 125, 337, 66, 130, 26, 4513, 2112, 15, 303, 146, 10, 283, 52, 178, 79, 149, 42], [31, 250, 1501, 54, 1267, 311, 2060, 143, 48, 91, 5, 476, 25, 932, 67, 2729, 37, 91, 5, 897, 3378, 54, 1634, 4128, 1879, 129, 193, 2844, 1501, 54, 2491, 504, 139, 6561, 2951, 672, 62, 271, 1135, 208, 2269, 4, 3, 480, 32, 4, 3, 250, 242, 1056, 584], [6562, 2, 50, 54, 3835, 180, 88, 44, 1009, 2061, 32, 2, 1042, 585, 252, 12, 296, 1759, 22, 1435], [2492, 72, 695, 1, 277, 2, 9, 29, 22, 49, 97, 132, 5677, 2270, 175, 6, 53, 268, 189, 56, 430, 292, 149, 804, 153, 62, 162, 319, 490, 181, 72, 17, 5, 792, 1066, 451, 889, 268, 426, 1436, 213, 4, 3, 37, 91, 5, 10, 73, 668, 118, 276, 7, 4981, 668, 1635, 9, 970, 847, 190, 221, 22, 88, 914, 1077, 41, 389, 305, 769], [6, 127, 1195, 465, 33, 1656, 168, 90, 20, 36, 3077, 2113, 20, 36, 30, 486, 1454, 19, 49, 1226, 141, 838, 744, 159, 4, 3, 133, 49, 1, 333, 915, 47, 80, 314, 620, 20, 36, 192, 467, 40, 1, 82, 1, 1304, 20, 36, 263, 701, 2, 43, 4, 3, 1119, 58, 107, 8, 13, 468, 20, 36, 433, 207], [8, 809, 6, 135, 4, 3, 1119, 1974, 31, 372, 20, 55, 117, 610, 2332, 117, 322, 1287, 141, 251, 62, 586, 5678, 809, 455, 331, 31, 313, 19, 167, 4982, 51, 331, 31, 4983, 331, 31, 435, 809, 180, 18, 200, 9050, 195], [750, 459, 1, 46, 1478, 402, 17, 10, 47, 1087, 553, 1760, 156, 345, 37, 628, 859, 48, 308, 24, 2, 5, 76, 9051, 64, 27, 19, 761, 1067, 94, 916, 30, 76, 51, 390, 130, 16, 243, 94, 30, 42, 125, 9052, 115, 156, 345, 1975, 6563, 1693, 283, 17, 13, 14, 114, 101, 408, 28, 126, 1693, 57, 77, 177, 13, 116, 10, 201, 27], [189, 97, 10, 284, 2845, 810, 268, 15, 101, 95, 6, 1414, 24, 80,  ...

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import numpy as np

# Tokenize the text data
tokenized_reviews = [word_tokenize(review.lower()) for review in review_train_df['review']]

# Train Word2Vec embeddings (or use pre-trained embeddings)
word2vec_model = Word2Vec(sentences=tokenized_reviews, vector_size=100, window=5, min_count=1, workers=4)

# Convert each review to a vector representation
review_vectors = []
for tokens in tokenized_reviews:
    # Compute the vector representation for each token
    token_vectors = []
    for token in tokens:
        if token in word2vec_model.wv:
            token_vectors.append(word2vec_model.wv[token])
    if token_vectors:
        # Aggregate token vectors (e.g., by averaging)
        review_vectors.append(np.mean(token_vectors, axis=0))
    else:
        # If no word in the review is in the vocabulary, use zero vector
        review_vectors.append(np.zeros(word2vec_model.vector_size))

# Convert review_vectors to numpy array
review_vectors = np.array(review_vectors)

# %%
from keras.layers import Input, Dense, LSTM, Bidirectional, GlobalMaxPooling1D
from keras.models import Model
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(review_vectors, review_train_df['condition'], test_size=0.25, random_state=42)

# Convert class labels to one-hot encoded vectors
num_classes = len(review_train_df['condition'].unique())

# Define the input shape (dimension of the vectors)
input_shape = (X_train.shape[1], 1)  # Assuming you have vectors of shape (100, 1)

# Define the architecture of the Bidirectional LSTM model
input_layer = Input(shape=input_shape)
x = Bidirectional(LSTM(128, return_sequences=True))(input_layer)
x = GlobalMaxPooling1D()(x)
output_layer = Dense(num_classes, activation='softmax')(x)  # Use softmax activation for multi-class classification

model = Model(inputs=input_layer, outputs=output_layer)

# Compile the model with categorical cross-entropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
model.fit(X_train, y_train, batch_size=100, epochs=30, validation_split=0.2,callbacks=[early_stopping])

# Evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100, 1)]          0
#
#  bidirectional_1 (Bidirecti  (None, 100, 256)          133120
#  onal)
#
#  global_max_pooling1d_1 (Gl  (None, 256)               0
#  obalMaxPooling1D)
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 133891 (523.01 KB)
# Trainable params: 133891 (523.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 84/84 [==============================] - 43s 443ms/step - loss: 0.8800 - accuracy: 0.6446 - val_loss: 0.8253 - val_accuracy: 0.6429
# Epoch 2/30
# 84/84 [==============================] - 40s 483ms/step - loss: 0.7007 - accuracy: 0.7040 - val_loss: 0.6494 - val_accuracy: 0.7471
# Epoch 3/30
# 84/84 [==============================] - 41s 490ms/step - loss: 0.6727 - accuracy: 0.7352 - val_loss: 0.6833 - val_accuracy: 0.7127
# Epoch 4/30
# 84/84 [==============================] - 38s 458ms/step - loss: 0.5983 - accuracy: 0.7712 - val_loss: 0.5612 - val_accuracy: 0.7768
# Epoch 5/30
# 84/84 [==============================] - 38s 457ms/step - loss: 0.5465 - accuracy: 0.7958 - val_loss: 0.4957 - val_accuracy: 0.8088
# Epoch 6/30
# 84/84 [==============================] - 38s 456ms/step - loss: 0.5082 - accuracy: 0.8158 - val_loss: 0.4592 - val_accuracy: 0.8250
# Epoch 7/30
# 84/84 [==============================] - 40s 473ms/step - loss: 0.4788 - accuracy: 0.8211 - val_loss: 0.4268 - val_accuracy: 0.8470
# Epoch 8/30
# 84/84 [==============================] - 38s 454ms/step - loss: 0.4399 - accuracy: 0.8364 - val_loss: 0.3968 - val_accuracy: 0.8537
# Epoch 9/30
# 84/84 [==============================] - 38s 454ms/step - loss: 0.4265 - accuracy: 0.8395 - val_loss: 0.4379 - val_accuracy: 0.8313
# Epoch 10/30
# 84/84 [==============================] - 39s 461ms/step - loss: 0.3987 - accuracy: 0.8526 - val_loss: 0.3767 - val_accuracy: 0.8700
# Epoch 11/30
# 84/84 [==============================] - 38s 445ms/step - loss: 0.3797 - accuracy: 0.8649 - val_loss: 0.3713 - val_accuracy: 0.8619
# Epoch 12/30
# 84/84 [==============================] - 40s 477ms/step - loss: 0.3660 - accuracy: 0.8667 - val_loss: 0.3442 - val_accuracy: 0.8843
# Epoch 13/30
# 84/84 [==============================] - 43s 513ms/step - loss: 0.3468 - accuracy: 0.8770 - val_loss: 0.3403 - val_accuracy: 0.8858
# Epoch 14/30
# 84/84 [==============================] - 43s 517ms/step - loss: 0.3375 - accuracy: 0.8749 - val_loss: 0.4645 - val_accuracy: 0.8227
# Epoch 15/30
# 84/84 [==============================] - 38s 455ms/step - loss: 0.3454 - accuracy: 0.8780 - val_loss: 0.3167 - val_accuracy: 0.8810
# Epoch 16/30
# 84/84 [==============================] - 38s 452ms/step - loss: 0.3338 - accuracy: 0.8790 - val_loss: 0.3124 - val_accuracy: 0.8838
# Epoch 17/30
# 84/84 [==============================] - 39s 464ms/step - loss: 0.3165 - accuracy: 0.8868 - val_loss: 0.3349 - val_accuracy: 0.8748
# Epoch 18/30
# 84/84 [==============================] - 38s 451ms/step - loss: 0.3199 - accuracy: 0.8831 - val_loss: 0.2927 - val_accuracy: 0.8987
# Epoch 19/30
# 84/84 [==============================] - 38s 456ms/step - loss: 0.3078 - accuracy: 0.8876 - val_loss: 0.3060 - val_accuracy: 0.8872
# Epoch 20/30
# 84/84 [==============================] - 44s 520ms/step - loss: 0.3024 - accuracy: 0.8915 - val_loss: 0.2965 - val_accuracy: 0.8905
# Epoch 21/30
# 84/84 [==============================] - 36s 429ms/step - loss: 0.2930 - accuracy: 0.8936 - val_loss: 0.2954 - val_accuracy: 0.8953
# 109/109 [==============================] - 10s 87ms/step - loss: 0.2985 - accuracy: 0.8956
# Test Loss: 0.29853367805480957
# Test Accuracy: 0.8955823183059692

# %%
# import matplotlib.pyplot as plt
# from sklearn.metrics import plot_confusion_matrix

# # Assuming 'pred' contains the predicted labels
# cm = confusion_matrix(y_test, y_pred)

# # Plot confusion matrix
# plt.figure(figsize=(8, 6))
# plot_confusion_matrix(model, X_test, y_test, display_labels=['Birth Control', 'Depression', 'Diabetes, Type 2', 'High Blood Pressure'])
# plt.title('Confusion Matrix')
# plt.show()import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

# Assuming 'pred' contains the predicted labels
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
plot_confusion_matrix(model, X_test, y_test, display_labels=['Birth Control', 'Depression', 'Diabetes, Type 2', 'High Blood Pressure'])
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-36-e999fc975ff3> in <cell line: 12>()
#      10 # plt.title('Confusion Matrix')
#      11 # plt.show()import matplotlib.pyplot as plt
# ---> 12 from sklearn.metrics import plot_confusion_matrix
#      13
#      14 # Assuming 'pred' contains the predicted labels
#
# ImportError: cannot import name 'plot_confusion_matrix' from 'sklearn.metrics' (/usr/local/lib/python3.10/dist-packages/sklearn/metrics/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
